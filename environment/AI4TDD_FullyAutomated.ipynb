# %% [markdown]
# # AI4TDD Experiment
#
#
# Thank you for participating in this experiment!
#
# Please insert the participant_id that was passed to you. If an OpenAI api key was also given to you, please insert it below.
#
# Then, run the cell.

# %%
openai_api_key = "" # @param {type:"string"}

import os

os.environ["PARTICIPANT_ID"] = -1
os.environ["OPEN_AI_KEY"] = openai_api_key

# %% [markdown]
# Now, please run the following cell.

# %%
import subprocess

# %% [markdown]
# Insert your test specification on in the below cell and execute it.

# %%
test_specification = ""

result = subprocess.run(["python", "ai4tdd-exp/runner.py", "--file", "ai4tdd-exp/experiment.py" "--interaction-mode", "CREATE_TEST_CODE", "--prompt", test_specification], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Print the command output
print(result.stdout)

# Print the command output
print(result.stderr)

# %% [raw]
# Once the test code was generated, execute the following cell, such the corresponding production code will be generated.

# %%
result = subprocess.run(["python", "ai4tdd-exp/runner.py", "--file", "ai4tdd-exp/experiment.py", "--interaction-mode", "CREATE_PRODUCTION_CODE"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Print the command output
print(result.stdout)

# Print the command output
print(result.stderr)

# %% [markdown]
# Once you completed the task, please run the following cell, download the zip and upload it in the form sent you.
#
# Not needed for local execution!

# %%
#!zip -r /content/file.zip /content/
#from google.colab import files
#files.download("/content/file.zip")
